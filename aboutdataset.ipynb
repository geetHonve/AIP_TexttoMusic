# %%
import pandas as pd
import numpy as np
import csv

# %%
data = pd.read_csv("/content/musiccaps-public.csv")
data
# Out:
#              ytid  start_s  end_s  \
# 0     -0Gj8-vB1q4       30     40
# 1     -0SdAVK79lg       30     40
# 2     -0vPFx-wRRI       30     40
# 3     -0xzrMun0Rs       30     40
# 4     -1LrH01Ei1w       30     40
# ...           ...      ...    ...
# 5516  zw5dkiklbhE       15     25
# 5517  zwfo7wnXdjs       30     40
# 5518  zx_vcwOsDO4       50     60
# 5519  zyXa2tdBTGc       30     40
# 5520  zzNdwF40ID8       70     80
#
#                                audioset_positive_labels  \
# 0                          /m/0140xf,/m/02cjck,/m/04rlf
# 1     /m/0155w,/m/01lyv,/m/0342h,/m/042v_gx,/m/04rlf...
# 2                                   /m/025_jnm,/m/04rlf
# 3                                    /m/01g90h,/m/04rlf
# 4                                   /m/02p0sh1,/m/04rlf
# ...                                                 ...
# 5516                                /m/01sm1g,/m/0l14md
# 5517                      /m/02p0sh1,/m/04rlf,/m/06j64v
# ...

# %%
# !pip install --upgrade pytube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install pytube3
# !pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pytube

def download_video_audio(url, output_dir):
    youtube = pytube.YouTube(url)
    video = youtube.streams.filter(only_audio=True).first()
    output_file = video.download(output_path=output_dir)
    return output_file

# %%
from pydub import AudioSegment

def convert_audio_to_midi(input_file, output_file):
    sound = AudioSegment.from_file(input_file)
    notes = sound.export(output_file, format="midi")
    return notes

# %%
urls = data['ytid']
data['midi'] = "https://www.youtube.com/watch?v=" + data['ytid']
i=0
data
# Out:
#              ytid  start_s  end_s  \
# 0     -0Gj8-vB1q4       30     40
# 1     -0SdAVK79lg       30     40
# 2     -0vPFx-wRRI       30     40
# 3     -0xzrMun0Rs       30     40
# 4     -1LrH01Ei1w       30     40
# ...           ...      ...    ...
# 5516  zw5dkiklbhE       15     25
# 5517  zwfo7wnXdjs       30     40
# 5518  zx_vcwOsDO4       50     60
# 5519  zyXa2tdBTGc       30     40
# 5520  zzNdwF40ID8       70     80
#
#                                audioset_positive_labels  \
# 0                          /m/0140xf,/m/02cjck,/m/04rlf
# 1     /m/0155w,/m/01lyv,/m/0342h,/m/042v_gx,/m/04rlf...
# 2                                   /m/025_jnm,/m/04rlf
# 3                                    /m/01g90h,/m/04rlf
# 4                                   /m/02p0sh1,/m/04rlf
# ...                                                 ...
# 5516                                /m/01sm1g,/m/0l14md
# 5517                      /m/02p0sh1,/m/04rlf,/m/06j64v
# ...

# %%
for di in data['ytid']:
    # Download audio from YouTube
    mp4_file = download_video_audio(data['midi'][i], data['midi'][i])
    
    # Convert audio to MIDI
    midi_file = mp4_file.replace('.mp4', '.mid')
    convert_audio_to_midi(mp4_file, midi_file)

    i += 1
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-15-46892e7d45c9> in <cell line: 1>()
#       1 for di in data['ytid']:
#       2     # Download audio from YouTube
# ----> 3     mp4_file = download_video_audio(data['midi'][i], data['midi'][i])
#       4
#       5     # Convert audio to MIDI
#
# <ipython-input-14-65253a283c39> in download_video_audio(url, output_dir)
#       2
#       3 def download_video_audio(url, output_dir):
# ----> 4     youtube = pytube.YouTube(url)
#       5     video = youtube.streams.filter(only_audio=True).first()
#       6     output_file = video.download(output_path=output_dir)
#
# /usr/local/lib/python3.9/dist-packages/pytube/__main__.py in __init__(self, url, defer_prefetch_init, on_progress_callback, on_complete_callback, proxies)
#      89
#      90         if not defer_prefetch_init:
# ---> 91             self.prefetch()
# ...
